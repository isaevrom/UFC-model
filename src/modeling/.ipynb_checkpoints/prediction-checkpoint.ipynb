# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data_cleaning/final data/data_2')
df.head(5).transpose()
# Out:
#                                          0                  1  \
# weight_division     Women's Flyweight Bout  Bantamweight Bout
# method                Decision - Unanimous             KO/TKO
# rounds                                   4                  1
# time                                   300                259
# rounds_format    ['5', '5', '5', '5', '5']    ['5', '5', '5']
# referee                         Mark Smith          Herb Dean
# Red_Name                      Alexa Grasso        Cub Swanson
# Red_Record                          15-3-0            28-13-0
# Red_Height                           165.1             172.72
# Red_Weight                            56.7               61.2
# Red_STANCE                        Orthodox           Orthodox
# Red_DOB                               1993               1983
# Red_SLpM                              5.14               4.68
# Red_Str. Acc.                           44                 50
# Red_SApM                              4.02               3.73
# Red_Str. Def                            61                 60
# Red_TD Avg.                           0.44               1.09
# Red_TD Acc.                             57                 52
# Red_TD Def.                             64                 61
# Red_Sub. Avg.                          0.6                0.4
# Blue_Name                   Viviane Araujo  Jonathan Martinez
# Blue_Record                         11-4-0             17-4-0
# Blue_Height                         162.56             172.72
# Blue_Weight                           56.7               61.2
# Blue_STANCE                       Orthodox           Southpaw
# Blue_DOB                              1986               1994
# Blue_SLpM                             4.82               4.84
# Blue_Str. Acc.                          48                 49
# Blue_SApM                             5.33               3.88
# Blue_Str. Def                           56                 58
# Blue_TD Avg.                          2.03               0.51
# Blue_TD Acc.                            48                 45
# Blue_TD Def.                            90                 70
# Blue_Sub. Avg.                         0.5                0.0
# Winner                        Alexa Grasso  Jonathan Martinez
# Red_Winrate                      83.333333          68.292683
# Blue_Winrate                     73.333333          80.952381
# Fight_Length %                       100.0          62.111111
#
#                                  2                     3  \
# weight_division  Middleweight Bout     Bantamweight Bout
# method                      KO/TKO  Decision - Unanimous
# rounds                           1                     2
# time                           192                   300
# rounds_format      ['5', '5', '5']       ['5', '5', '5']
# referee              Chris Tognoni          Kerry Hatley
# Red_Name             Jordan Wright      Raphael Assuncao
# Red_Record           12-4-0 (1 NC)                28-9-0
# Red_Height                  187.96                 165.1
# Red_Weight                    83.9                  61.2
# Red_STANCE                Orthodox              Orthodox
# Red_DOB                       1991                  1982
# Red_SLpM                      5.67                  3.24
# Red_Str. Acc.                   65                    41
# Red_SApM                      7.54                  2.41
# Red_Str. Def                    32                    67
# Red_TD Avg.                    3.6                  1.47
# Red_TD Acc.                     50                    38
# Red_TD Def.                    100                    78
# Red_Sub. Avg.                  0.7                   0.3
# Blue_Name          Dusko Todorovic          Victor Henry
# Blue_Record                 12-3-0                22-6-0
# Blue_Height                 185.42                170.18
# Blue_Weight                   83.9                  61.2
# Blue_STANCE               Orthodox                Switch
# Blue_DOB                      1994                  1987
# Blue_SLpM                     5.64                  7.87
# Blue_Str. Acc.                  57                    49
# Blue_SApM                     4.54                  6.47
# Blue_Str. Def                   47                    47
# Blue_TD Avg.                  0.99                   0.0
# Blue_TD Acc.                    12                     0
# Blue_TD Def.                    45                    75
# Blue_Sub. Avg.                 0.0                   0.0
# Winner             Dusko Todorovic      Raphael Assuncao
# Red_Winrate                   75.0             75.675676
# Blue_Winrate                  80.0             78.571429
# Fight_Length %           54.666667                 100.0
#
#                                       4
# weight_division  Light Heavyweight Bout
# method                           KO/TKO
# rounds                                0
# time                                 88
# rounds_format           ['5', '5', '5']
# referee                      Mark Smith
# Red_Name                 Misha Cirkunov
# Red_Record                       15-9-0
# Red_Height                        190.5
# Red_Weight                         93.0
# Red_STANCE                     Orthodox
# Red_DOB                            1987
# Red_SLpM                           3.86
# Red_Str. Acc.                        51
# Red_SApM                           3.06
# Red_Str. Def                         57
# Red_TD Avg.                        4.15
# Red_TD Acc.                          39
# Red_TD Def.                          76
# Red_Sub. Avg.                       1.7
# Blue_Name              Alonzo Menifield
# Blue_Record                      13-3-0
# Blue_Height                      182.88
# Blue_Weight                        93.0
# Blue_STANCE                    Orthodox
# Blue_DOB                           1987
# Blue_SLpM                          3.91
# Blue_Str. Acc.                       56
# Blue_SApM                          3.24
# Blue_Str. Def                        52
# Blue_TD Avg.                       0.81
# Blue_TD Acc.                         30
# Blue_TD Def.                         85
# Blue_Sub. Avg.                      0.2
# Winner                 Alonzo Menifield
# Red_Winrate                        62.5
# Blue_Winrate                      81.25
# Fight_Length %                 9.777778

# %%
non_predictive_columns = [
    'method',
    'rounds', 'time', 'rounds_format',
    'Red_Record', 'Blue_Record',
    'Fight_Length %'
]

data = df.drop(columns=non_predictive_columns).copy()

# %%
data.head(5).transpose()
# Out:
#                                       0                  1                  2  \
# weight_division  Women's Flyweight Bout  Bantamweight Bout  Middleweight Bout
# referee                      Mark Smith          Herb Dean      Chris Tognoni
# Red_Name                   Alexa Grasso        Cub Swanson      Jordan Wright
# Red_Height                        165.1             172.72             187.96
# Red_Weight                         56.7               61.2               83.9
# Red_STANCE                     Orthodox           Orthodox           Orthodox
# Red_DOB                            1993               1983               1991
# Red_SLpM                           5.14               4.68               5.67
# Red_Str. Acc.                        44                 50                 65
# Red_SApM                           4.02               3.73               7.54
# Red_Str. Def                         61                 60                 32
# Red_TD Avg.                        0.44               1.09                3.6
# Red_TD Acc.                          57                 52                 50
# Red_TD Def.                          64                 61                100
# Red_Sub. Avg.                       0.6                0.4                0.7
# Blue_Name                Viviane Araujo  Jonathan Martinez    Dusko Todorovic
# Blue_Height                      162.56             172.72             185.42
# Blue_Weight                        56.7               61.2               83.9
# Blue_STANCE                    Orthodox           Southpaw           Orthodox
# Blue_DOB                           1986               1994               1994
# Blue_SLpM                          4.82               4.84               5.64
# Blue_Str. Acc.                       48                 49                 57
# Blue_SApM                          5.33               3.88               4.54
# Blue_Str. Def                        56                 58                 47
# Blue_TD Avg.                       2.03               0.51               0.99
# Blue_TD Acc.                         48                 45                 12
# Blue_TD Def.                         90                 70                 45
# Blue_Sub. Avg.                      0.5                0.0                0.0
# Winner                     Alexa Grasso  Jonathan Martinez    Dusko Todorovic
# Red_Winrate                   83.333333          68.292683               75.0
# Blue_Winrate                  73.333333          80.952381               80.0
#
#                                  3                       4
# weight_division  Bantamweight Bout  Light Heavyweight Bout
# referee               Kerry Hatley              Mark Smith
# Red_Name          Raphael Assuncao          Misha Cirkunov
# Red_Height                   165.1                   190.5
# Red_Weight                    61.2                    93.0
# Red_STANCE                Orthodox                Orthodox
# Red_DOB                       1982                    1987
# Red_SLpM                      3.24                    3.86
# Red_Str. Acc.                   41                      51
# Red_SApM                      2.41                    3.06
# Red_Str. Def                    67                      57
# Red_TD Avg.                   1.47                    4.15
# Red_TD Acc.                     38                      39
# Red_TD Def.                     78                      76
# Red_Sub. Avg.                  0.3                     1.7
# Blue_Name             Victor Henry        Alonzo Menifield
# Blue_Height                 170.18                  182.88
# Blue_Weight                   61.2                    93.0
# Blue_STANCE                 Switch                Orthodox
# Blue_DOB                      1987                    1987
# Blue_SLpM                     7.87                    3.91
# Blue_Str. Acc.                  49                      56
# Blue_SApM                     6.47                    3.24
# Blue_Str. Def                   47                      52
# Blue_TD Avg.                   0.0                    0.81
# Blue_TD Acc.                     0                      30
# Blue_TD Def.                    75                      85
# Blue_Sub. Avg.                 0.0                     0.2
# Winner            Raphael Assuncao        Alonzo Menifield
# Red_Winrate              75.675676                    62.5
# Blue_Winrate             78.571429                   81.25

# %% [markdown]
# # Encoding dependent variable
# - Red corner fighter **won** the fight  => Winner value is 1
# - Red corner fighter **lost** the fight => Winner value is 0

# %%
y = data.apply(lambda x: x.Winner == x.Red_Name, axis=1).astype(int).copy()
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 6432    1
# 6433    1
# 6434    1
# 6435    1
# 6436    1
# Length: 6437, dtype: int64

# %% [markdown]
# # Preparing data for prediction
# #### (Note: after playing around with it I ended up using scaled version of dataframe X_D)
# - X_A:
#     - applying One Hot Encoding on **all of the object features**
# - X_B:
#     - applying OHE on **referee column only**, as it is probably the most important feature; dropping the rest
# - X_C:
#     - applying OHE on **all of the object features**, but **dropping referee** column, as it is also the highest cardinality categorical feature, having more than 200 unique values
# - X_D:
#     - **dropping all** of the categorical features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = data.drop(columns=['Red_Name', 'Blue_Name', 'Winner']).copy()
X = X.reindex(sorted(X.columns), axis=1)
X.head(5).transpose();

# %%
# X_A ... all
X_A = X
# X_B ... referee
X_B = X.drop(columns=['weight_division', 'Red_STANCE', 'Blue_STANCE'])
# X_C ... all - referee
X_C = X.drop(columns=['referee'])
# X_D ... droping all
categorical_cols = [col for col in data.drop(columns=['Red_Name', 'Blue_Name', 'Winner']) if df[col].dtype == 'O']
X_D = X.drop(columns=categorical_cols)
X_D = pd.concat([X_D], axis=1, sort=True)
# also creating normalized version of X_D
scaler_mm = MinMaxScaler()
X_D_scaled = pd.DataFrame(scaler_mm.fit_transform(X_D),
                          index=X_D.index,
                          columns=X_D.columns)

# %%
X_A = pd.get_dummies(X_A)
X_A;

# %%
X_B = pd.get_dummies(X_B)
X_B;

# %%
X_C = pd.get_dummies(X_C)
X_C;

# %%
import seaborn as sns
import numpy as np

f, ax = plt.subplots(figsize=(10, 8))
corr = X.loc[:, ['Red_SLpM', 'Red_SApM', 'Red_TD Def.', 'Red_Winrate']].corr()
corr = X_D.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()
# Out:
# /var/folders/v8/qxrt4y911pz305_jrps2skrr0000gn/T/ipykernel_29000/3457401587.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),

# %% [markdown]
# # Trying different models:
# - **Random Forest**
#     - generally good and widely used model
# - **XGBoost**
#     - this model is shown to be successful particularly for predictions of outcomes of matches, as its good at finding complex relationships in data
#     - many Kaggle competitions winners owe their victory to XGBoost

# %%
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

from sklearn.model_selection import train_test_split

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score

# %%
X_D.head(5).transpose()
# Out:
#                           0            1        2            3        4
# Blue_DOB        1986.000000  1994.000000  1994.00  1987.000000  1987.00
# Blue_Height      162.560000   172.720000   185.42   170.180000   182.88
# Blue_SApM          5.330000     3.880000     4.54     6.470000     3.24
# Blue_SLpM          4.820000     4.840000     5.64     7.870000     3.91
# Blue_Str. Acc.    48.000000    49.000000    57.00    49.000000    56.00
# Blue_Str. Def     56.000000    58.000000    47.00    47.000000    52.00
# Blue_Sub. Avg.     0.500000     0.000000     0.00     0.000000     0.20
# Blue_TD Acc.      48.000000    45.000000    12.00     0.000000    30.00
# Blue_TD Avg.       2.030000     0.510000     0.99     0.000000     0.81
# Blue_TD Def.      90.000000    70.000000    45.00    75.000000    85.00
# Blue_Weight       56.700000    61.200000    83.90    61.200000    93.00
# Blue_Winrate      73.333333    80.952381    80.00    78.571429    81.25
# Red_DOB         1993.000000  1983.000000  1991.00  1982.000000  1987.00
# Red_Height       165.100000   172.720000   187.96   165.100000   190.50
# Red_SApM           4.020000     3.730000     7.54     2.410000     3.06
# Red_SLpM           5.140000     4.680000     5.67     3.240000     3.86
# Red_Str. Acc.     44.000000    50.000000    65.00    41.000000    51.00
# Red_Str. Def      61.000000    60.000000    32.00    67.000000    57.00
# Red_Sub. Avg.      0.600000     0.400000     0.70     0.300000     1.70
# Red_TD Acc.       57.000000    52.000000    50.00    38.000000    39.00
# Red_TD Avg.        0.440000     1.090000     3.60     1.470000     4.15
# Red_TD Def.       64.000000    61.000000   100.00    78.000000    76.00
# Red_Weight        56.700000    61.200000    83.90    61.200000    93.00
# Red_Winrate       83.333333    68.292683    75.00    75.675676    62.50

# %%
X_train, X_test, y_train, y_test = train_test_split(X_D_scaled,
                                                    y,
                                                    test_size=0.25, 
                                                    random_state=123,
                                                    stratify=y)

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# * Tuning model by finding best hyperparameters

# %%
rfc  = RandomForestClassifier()
params = {
 'bootstrap': [True, False],
 'max_depth': [5, 10, 15],
 'max_features': ['sqrt'],
 'min_samples_leaf': [1, 2, 4, 8],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [50, 75, 150, 250]
}
rfc_random = RandomizedSearchCV(estimator=rfc, 
                                param_distributions=params, 
                                n_iter=25, 
                                cv=5, 
                                scoring='roc_auc',
                                n_jobs=4,
                                verbose=1, 
                                random_state=42)
rfc_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=25,
#                    n_jobs=4,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 10, 15],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_leaf': [1, 2, 4, 8],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 75, 150, 250]},
#                    random_state=42, scoring='roc_auc', verbose=1)

# %% [markdown]
# * Best hyperparameters for **Random Forest Classifier**:

# %%
best_params = rfc_random.best_params_
best_params
# Out:
# {'n_estimators': 250,
#  'min_samples_split': 2,
#  'min_samples_leaf': 4,
#  'max_features': 'sqrt',
#  'max_depth': 10,
#  'bootstrap': True}

# %%
best_rfc = RandomForestClassifier(**best_params)
best_rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=250)

# %%
y_pred = best_rfc.predict(X_test)

# %%
print(classification_report(y_test, y_pred, labels=sorted(best_rfc.classes_, reverse=True)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.74      0.89      0.81      1049
#            0       0.67      0.42      0.52       561
#
#     accuracy                           0.73      1610
#    macro avg       0.71      0.65      0.66      1610
# weighted avg       0.72      0.73      0.71      1610

# %%
# saving accuracy of RF
rf_acc = accuracy_score(y_test, y_pred)
# saving average f1-score of RF
rf_score_dict = classification_report(y_test, y_pred, 
                                      labels=sorted(best_rfc.classes_, reverse=True), 
                                      output_dict=True)
rf_f1 = rf_score_dict['macro avg']['f1-score']

print(f'accuracy: {rf_acc}')
print(f'f1-score: {rf_f1}')
# Out:
# accuracy: 0.7260869565217392
# f1-score: 0.6624624019312584

# %% [markdown]
# ## XGBoost

# %% [markdown]
# * Tuning model by finding best hyperparameters

# %%
xgbc = xgb.XGBClassifier(learning_rate=0.02, objective='binary:logistic')
params = {
        'min_child_weight': [1, 5, 10, 15],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5],
        'n_estimators': [150, 250, 350]
}
random_search = RandomizedSearchCV(xgbc,
                                   param_distributions=params, 
                                   n_iter=5, 
                                   cv=5,
                                   scoring='roc_auc', 
                                   n_jobs=4, 
                                   verbose=1, 
                                   random_state=1001)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=None,
#                                            gpu_id=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=0.02, max_bin=None,...
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None,
#                                            reg_alpha=None, reg_lambda=None, ...),
#                    n_iter=5, n_jobs=4,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'max_depth': [3, 4, 5],
#                                         'min_child_weight': [1, 5, 10, 15],
#                                         'n_estimators': [150, 250, 350],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=1001, scoring='roc_auc', verbose=1)

# %% [markdown]
# * Best hyperparameters for **XGBoost**:

# %%
best_params_xgbc = random_search.best_params_
best_params_xgbc
# Out:
# {'subsample': 0.8,
#  'n_estimators': 350,
#  'min_child_weight': 15,
#  'max_depth': 4,
#  'gamma': 1.5,
#  'colsample_bytree': 0.6}

# %%
best_xgbc = xgb.XGBClassifier(learning_rate=0.02, 
                              objective='binary:logistic',
                              silent=True,
                              **best_params_xgbc)
best_xgbc.fit(X_train, y_train)
# Out:
# [22:28:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1665562906201/work/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=1.5, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.02, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=15,
#               missing=nan, monotone_constraints='()', n_estimators=350,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = best_xgbc.predict(X_test)
xgb_acc = accuracy_score(y_test, y_pred)
xgb_f1  = f1_score(y_test, y_pred)

# %%
print(f'accuracy: {xgb_acc}')
print(f'f1-score: {xgb_f1}')
print(classification_report(y_test, y_pred, labels=sorted(best_xgbc.classes_, reverse=True)))
# Out:
# accuracy: 0.7329192546583851
# f1-score: 0.807347670250896
#               precision    recall  f1-score   support
#
#            1       0.76      0.86      0.81      1049
#            0       0.65      0.50      0.56       561
#
#     accuracy                           0.73      1610
#    macro avg       0.71      0.68      0.69      1610
# weighted avg       0.72      0.73      0.72      1610

# %%
# saving accuracy of XGB
xgb_acc = accuracy_score(y_test, y_pred)
# saving average f1-score of XGB
xgb_score_dict = classification_report(y_test, y_pred,
                                       labels=sorted(best_xgbc.classes_, reverse=True),
                                       output_dict=True)
xgb_f1 = xgb_score_dict['macro avg']['f1-score']

print(f'accuracy: {xgb_acc}')
print(f'f1-score: {xgb_f1}')
# Out:
# accuracy: 0.7329192546583851
# f1-score: 0.6860624990930593

# %% [markdown]
# ## Comparing the two

# %% [markdown]
# * As we can see below, both of the models are pretty much equally good when it comes to the **False Positives** and **True Positives** ratio. With slightly better score for XGBoost

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

classifiers = [best_rfc, best_xgbc]

model_names = {
    best_rfc: 'RandomForest',
    best_xgbc:'XGBoost',
}

plt.figure(figsize=(5,5), dpi=150)

for clf in classifiers:
    y_pred = clf.predict_proba(X_test)[:,1] 
    
    fpr, tpr, threshhold = roc_curve(y_test, y_pred)
    _auc = auc(fpr, tpr)
    
    plt.plot(fpr, tpr, linestyle='-', 
             label=f'{model_names[clf]}: AUC = {_auc:.3f}')
    
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * Let's take a look at **f1-score** and **accuracy**:
#     * As shown below, XGBoost has slightly better both accuracy & f1-score

# %%
x_axis = np.arange(2)
labels = ['Random Forest','XGBoost']

accs = [rf_acc, xgb_acc]
f1s  = [rf_f1, xgb_f1]

plt.figure(figsize = (12, 7.5)) 

# bars for f1-score
bars_f1 = plt.bar(x_axis - 0.2, 
        f1s,  
        width=0.4,  
        label = 'f1-score (avg)')

for bar in bars_f1:
    score = bar.get_height()
    plt.text(bar.get_x() + 0.15, score + .005, np.round(score, 4))

# bars for accuracy
bars_acc = plt.bar(x_axis + 0.2, 
        accs, 
        width=0.4,
        label = 'accuracy')

for bar in bars_acc:
    score = bar.get_height()
    plt.text(bar.get_x() + 0.15, score + .005, np.round(score, 4))

plt.xticks(x_axis, labels)
plt.xlabel("Model")
plt.ylabel("Score of metric")
plt.title("Impact of model choice on classification outcome")
plt.legend()
plt.show()

# %% [markdown]
# ## Feature importance:

# %%
assert len(best_xgbc.feature_names_in_) == len(best_xgbc.feature_importances_)

# %%
feat_imp = dict()
for feature, importance in zip(best_xgbc.feature_names_in_, best_xgbc.feature_importances_):
    feat_imp[feature] = 100 * importance
feat_imp;

# %%
ax = pd.Series(data=feat_imp).sort_values(ascending=True).plot(kind='barh',
                                                               figsize=(10,10))
ax.bar_label(ax.containers[0], 
             fmt='%.2f',
             padding=1.5)
    
plt.title('Importance Of Features')
plt.xlabel('% Feature importance') 
plt.ylabel('Feature name')
plt.show()

# %% [markdown]
# # Bonus: UFC-280 predictions
# * Models have not seen UFC-280 data yet, as that data was not present at time of scraping
# * Let's see how well they predict outcomes of UFC-280 fights

# %%
red_cols  = [col for col in data.columns if col.startswith('Red_')]
blue_cols = [col for col in data.columns if col.startswith('Blue_')]

# %%
def get_winner(clf, red_name, blue_name):
    print(f'{red_name} vs. {blue_name}')
    
    red  = data[data.Red_Name.str.startswith(red_name)].head(1)[red_cols].drop(columns=['Red_Name', 'Red_STANCE'])
    if red.shape[0] == 0:
        red  = data[data.Blue_Name.str.startswith(red_name)].head(1)[blue_cols].drop(columns=['Blue_Name', 'Blue_STANCE'])
        red = red.rename(columns={i: 'Red_' + i[5:] for i in X_D_scaled.columns if i.startswith('Blue_') })
        
    blue = data[data.Blue_Name.str.startswith(blue_name)].head(1)[blue_cols].drop(columns=['Blue_Name', 'Blue_STANCE'])
    if blue.shape[0] == 0:
        blue  = data[data.Red_Name.str.startswith(blue_name)].head(1)[red_cols].drop(columns=['Red_Name', 'Red_STANCE'])
        blue = blue.rename(columns={i: 'Blue_' + i[4:] for i in X_D_scaled.columns if i.startswith('Red_') })
    
    red = red.reset_index(drop=True)
    blue = blue.reset_index(drop=True)
    
    fight = pd.concat([red, blue], axis=1, sort=True)
    fight = fight.reindex(sorted(fight.columns), axis=1)
    print(clf.predict(pd.DataFrame(scaler_mm.transform(fight),
                                   columns=X_D_scaled.columns)))
    return clf.predict(pd.DataFrame(scaler_mm.transform(fight),
                                   columns=X_D_scaled.columns))

# %%
def event_prediction(clf, event):
    list_pred = []
    # getting prediction for each fight
    for fight in ufc280:
        prediction = get_winner(clf=clf, 
                                red_name=fight[0], 
                                blue_name=fight[1])
        # using idx [0] just to transform one-element array to number
        list_pred.append(prediction[0])
    number_of_fights = len(event)
    # real_outcomes is just an array of ones
    real_outcomes = [1 for i in range(number_of_fights)]
    # indicates number of fights which outcome prediction is correct
    correct = 0
    for i in range(len(real_outcomes)):
        if list_pred[i] == real_outcomes[i]:
            correct += 1
    ratio = correct/float(number_of_fights) * 100
    print(f'{ratio}% of fight outcomes predicted correctly')
    return ratio

# %%
ufc280 = [
    ['Islam Makhachev', 'Charles Oliveira'],
    ['Aljamain Sterling', 'TJ Dillashaw'],
    ['Sean O\'Malley', 'Petr Yan'],
    ['Beneil Dariush', 'Mateusz Gamrot'],
    ['Manon Fiorot', 'Katlyn Chookagian'],
    ['Belal Muhammad', 'Sean Brady'],
    ['Caio Borralho', 'Makhmud Muradov'],
    ['Nikita Krylov', 'Volkan Oezdemir'],
    ['Armen Petrosyan', 'AJ Dobson'],
    ['Abubakar Nurmagomedov', 'Gadzhi Omargadzhiev'],
    ['Muhammad Mokaev', 'Malcolm Gordon'],
    ['Karol Rosa', 'Lina Lansberg']
]

# %%
def plot_pie(ratio, clf_name):
    correct = ratio
    incorrect = 100 - ratio
    sizes = [correct, incorrect]
    
    explode = (0, 0.125)  # only "explode" the 2nd slice (i.e. 'Hogs')
    
    fig, ax = plt.subplots()
    ax.pie(sizes,
           explode=explode,
           shadow=True,
           startangle=90,
           autopct='%1.2f%%')
    plt.title(f'UFC-280 predictions ratio ({clf_name})')
    plt.legend(['Correctly predicted', 'Incorrectly predicted'])
    plt.show()

# %% [markdown]
# ## Random Forest

# %%
rf_ratio = event_prediction(best_rfc, ufc280)
plot_pie(rf_ratio, clf_name='Random Forest')
# Out:
# Islam Makhachev vs. Charles Oliveira
# [1]
# Aljamain Sterling vs. TJ Dillashaw
# [1]
# Sean O'Malley vs. Petr Yan
# [1]
# Beneil Dariush vs. Mateusz Gamrot
# [0]
# Manon Fiorot vs. Katlyn Chookagian
# [1]
# Belal Muhammad vs. Sean Brady
# [0]
# Caio Borralho vs. Makhmud Muradov
# [1]
# Nikita Krylov vs. Volkan Oezdemir
# [1]
# Armen Petrosyan vs. AJ Dobson
# [0]
# Abubakar Nurmagomedov vs. Gadzhi Omargadzhiev
# [1]
# Muhammad Mokaev vs. Malcolm Gordon
# [1]
# Karol Rosa vs. Lina Lansberg
# [1]
# 75.0% of fight outcomes predicted correctly

# %% [markdown]
# ## XGBoost

# %%
xgb_ratio = event_prediction(best_xgbc, ufc280)
plot_pie(xgb_ratio, clf_name='XGBoost')
# Out:
# Islam Makhachev vs. Charles Oliveira
# [1]
# Aljamain Sterling vs. TJ Dillashaw
# [1]
# Sean O'Malley vs. Petr Yan
# [1]
# Beneil Dariush vs. Mateusz Gamrot
# [0]
# Manon Fiorot vs. Katlyn Chookagian
# [1]
# Belal Muhammad vs. Sean Brady
# [1]
# Caio Borralho vs. Makhmud Muradov
# [1]
# Nikita Krylov vs. Volkan Oezdemir
# [1]
# Armen Petrosyan vs. AJ Dobson
# [0]
# Abubakar Nurmagomedov vs. Gadzhi Omargadzhiev
# [1]
# Muhammad Mokaev vs. Malcolm Gordon
# [1]
# Karol Rosa vs. Lina Lansberg
# [1]
# 83.33333333333334% of fight outcomes predicted correctly

# %% [markdown]
# # End.
