# %%
import pandas as pd

# %%
df = pd.read_csv('final data/data')

# %%
df
# Out:
#                       weight                   method  rounds   time  \
# 0     Women's Flyweight Bout     Decision - Unanimous       5   5:00
# 1          Bantamweight Bout                   KO/TKO       2   4:19
# 2          Middleweight Bout                   KO/TKO       2   3:12
# 3          Bantamweight Bout     Decision - Unanimous       3   5:00
# 4     Light Heavyweight Bout                   KO/TKO       1   1:28
# ...                      ...                      ...     ...    ...
# 6505       Middleweight Bout               Submission       1  12:00
# 6506        Heavyweight Bout     Decision - Unanimous       2   3:00
# 6507       Middleweight Bout                   KO/TKO       1   2:58
# 6508        Heavyweight Bout               Submission       1   1:56
# 6509        Heavyweight Bout  TKO - Doctor's Stoppage       1  10:01
#
#           rounds_format        referee          Red_Name      Red_Record  \
# ...
